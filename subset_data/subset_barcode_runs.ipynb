# %% [markdown]
# # Subset barcode runs
# This Python Jupyter notebook is creates a copy of the barcode runs file that contains just specific samples.
#
# First, import Python modules:

# %%
import os

import pandas as pd

import yaml

# %% [markdown]
# Read in the "master" barcode runs CSV file and the runs used to compute the escape scores for each sample:

# %%
with open('../config.yaml') as f:
    config = yaml.safe_load(f)

barcode_runs_file = os.path.join('../', config['barcode_runs'])
print(f"Reading barcode runs from {barcode_runs_file}")
barcode_runs = pd.read_csv(barcode_runs_file)

escape_score_samples_file = os.path.join('../', config['escape_score_samples'])
print(f"Reading escape score samples from {escape_score_samples_file}")
escape_score_samples = pd.read_csv(escape_score_samples_file)
# Out:
# Reading barcode runs from ../data/barcode_runs.csv
# Reading escape score samples from ../results/escape_scores/samples.csv

# %% [markdown]
# Now read in the samples to subset:

# %%
samples_to_subset_df = pd.read_csv('samples_to_subset.csv')
print('Here are the samples we will subset to:')
display(samples_to_subset_df)

samples_to_subset = samples_to_subset_df['sample'].tolist()
assert len(samples_to_subset) == len(set(samples_to_subset)), 'duplicate samples to subset'
# Out:
# Here are the samples we will subset to:
#            sample
# 0        S309_421
# 1         S304_46
# 2        S2X35_70
# 3        S2H97_58
# 4        S2E12_56
# 5        S2H58_46
# 6        S2X16_54
# 7       S2D106_68
# 8        S2X58_18
# 9        S2H13_56
# 10      S2H14_105
# 11     S2X227_138
# 12        CB6_400
# 13  REGN10933_400
# 14  REGN10987_400
# 15     CR3022_400
# 16  COV2-2677_400
# 17  COV2-2082_400
# 18  COV2-2094_400
# 19  COV2-2165_400
# 20  COV2-2832_400
# 21  COV2-2479_400
# 22  COV2-2050_400
# 23  COV2-2096_400
# 24  COV2-2499_400
# 25  COV2-2196_400
# 26  COV2-2130_400
# 27  LY-CoV555_400
# 28      S2X259_59

# %% [markdown]
# Now get all the escape-score samples of interest:

# %%
if not set(samples_to_subset).issubset(escape_score_samples['name']):
    raise ValueError(f"Not all samples to subset are in the escape score samples.")
    
samples_subset = (
    escape_score_samples
    .query('name in @samples_to_subset')
    .reset_index(drop=True)
    )

print(f"Here are the samples for which we are subsetting barcode runs:")
display(samples_subset)
# Out:
# Here are the samples for which we are subsetting barcode runs:
#              name library   antibody concentration concentration_units  \
# 0         CB6_400    lib1        CB6           400           ng_per_mL
# 1         CB6_400    lib2        CB6           400           ng_per_mL
# 2   COV2-2050_400    lib1  COV2-2050           400           ng_per_mL
# 3   COV2-2050_400    lib2  COV2-2050           400           ng_per_mL
# 4   COV2-2082_400    lib1  COV2-2082           400           ng_per_mL
# 5   COV2-2082_400    lib2  COV2-2082           400           ng_per_mL
# 6   COV2-2094_400    lib1  COV2-2094           400           ng_per_mL
# 7   COV2-2094_400    lib2  COV2-2094           400           ng_per_mL
# 8   COV2-2096_400    lib1  COV2-2096           400           ng_per_mL
# 9   COV2-2096_400    lib2  COV2-2096           400           ng_per_mL
# 10  COV2-2130_400    lib1  COV2-2130           400           ng_per_mL
# 11  COV2-2130_400    lib2  COV2-2130           400           ng_per_mL
# 12  COV2-2165_400    lib1  COV2-2165           400           ng_per_mL
# 13  COV2-2165_400    lib2  COV2-2165           400           ng_per_mL
# 14  COV2-2196_400    lib1  COV2-2196           400           ng_per_mL
# 15  COV2-2196_400    lib2  COV2-2196           400           ng_per_mL
# 16  COV2-2479_400    lib1  COV2-2479           400           ng_per_mL
# 17  COV2-2479_400    lib2  COV2-2479           400           ng_per_mL
# 18  COV2-2499_400    lib1  COV2-2499           400           ng_per_mL
# 19  COV2-2499_400    lib2  COV2-2499           400           ng_per_mL
# 20  COV2-2677_400    lib1  COV2-2677           400           ng_per_mL
# 21  COV2-2677_400    lib2  COV2-2677           400           ng_per_mL
# 22  COV2-2832_400    lib1  COV2-2832           400           ng_per_mL
# 23  COV2-2832_400    lib2  COV2-2832           400           ng_per_mL
# 24     CR3022_400    lib1     CR3022           400           ng_per_mL
# 25     CR3022_400    lib2     CR3022           400           ng_per_mL
# 26  LY-CoV555_400    lib1  LY-CoV555           400           ng_per_mL
# 27  LY-CoV555_400    lib2  LY-CoV555           400           ng_per_mL
# 28  REGN10933_400    lib1  REGN10933           400           ng_per_mL
# 29  REGN10933_400    lib2  REGN10933           400           ng_per_mL
# 30  REGN10987_400    lib1  REGN10987           400           ng_per_mL
# 31  REGN10987_400    lib2  REGN10987           400           ng_per_mL
# 32      S2D106_68    lib1     S2D106            68           ng_per_mL
# 33      S2D106_68    lib2     S2D106            68           ng_per_mL
# 34       S2E12_56    lib1      S2E12            56           ng_per_mL
# 35       S2E12_56    lib2      S2E12            56           ng_per_mL
# 36       S2H13_56    lib1      S2H13            56           ng_per_mL
# 37       S2H13_56    lib2      S2H13            56           ng_per_mL
# 38      S2H14_105    lib1      S2H14           105           ng_per_mL
# 39      S2H14_105    lib2      S2H14           105           ng_per_mL
# 40       S2H58_46    lib1      S2H58            46           ng_per_mL
# 41       S2H58_46    lib2      S2H58            46           ng_per_mL
# 42       S2H97_58    lib1      S2H97            58           ng_per_mL
# 43       S2H97_58    lib2      S2H97            58           ng_per_mL
# 44       S2X16_54    lib1      S2X16            54           ng_per_mL
# 45       S2X16_54    lib2      S2X16            54           ng_per_mL
# 46     S2X227_138    lib1     S2X227           138           ng_per_mL
# 47     S2X227_138    lib2     S2X227           138           ng_per_mL
# 48      S2X259_59    lib1     S2X259            59           ng_per_mL
# 49      S2X259_59    lib2     S2X259            59           ng_per_mL
# 50       S2X35_70    lib1      S2X35            70           ng_per_mL
# 51       S2X35_70    lib2      S2X35            70           ng_per_mL
# 52       S2X58_18    lib1      S2X58            18           ng_per_mL
# 53       S2X58_18    lib2      S2X58            18           ng_per_mL
# 54        S304_46    lib1       S304            46           ng_per_mL
# 55        S304_46    lib2       S304            46           ng_per_mL
# 56       S309_421    lib1       S309           421           ng_per_mL
# 57       S309_421    lib2       S309           421           ng_per_mL
#
#       date                   pre_sample                   post_sample  \
# 0   200904  expt_24-33-none-0-reference        expt_27-CB6-400-escape
# 1   200904  expt_24-33-none-0-reference        expt_27-CB6-400-escape
# 2   200720  expt_13-16-none-0-reference  expt_13-COV2-2050-400-escape
# 3   200720  expt_13-16-none-0-reference  expt_13-COV2-2050-400-escape
# 4   200616   expt_7-11-none-0-reference  expt_11-COV2-2082-400-escape
# 5   200616   expt_7-11-none-0-reference  expt_11-COV2-2082-400-escape
# 6   200720  expt_13-16-none-0-reference  expt_14-COV2-2094-400-escape
# 7   200720  expt_13-16-none-0-reference  expt_14-COV2-2094-400-escape
# 8   200810  expt_22-23-none-0-reference  expt_23-COV2-2096-400-escape
# 9   200810  expt_22-23-none-0-reference  expt_23-COV2-2096-400-escape
# 10  201102  expt_65-67-none-0-reference  expt_66-COV2-2130-400-escape
# 11  201102  expt_65-67-none-0-reference  expt_66-COV2-2130-400-escape
# 12  200616   expt_7-11-none-0-reference   expt_9-COV2-2165-400-escape
# 13  200616   expt_7-11-none-0-reference   expt_9-COV2-2165-400-escape
# 14  201102  expt_65-67-none-0-reference  expt_65-COV2-2196-400-escape
# 15  201102  expt_65-67-none-0-reference  expt_65-COV2-2196-400-escape
# 16  200615    expt_3-6-none-0-reference   expt_5-COV2-2479-400-escape
# 17  200615    expt_3-6-none-0-reference   expt_5-COV2-2479-400-escape
# 18  200720  expt_13-16-none-0-reference  expt_15-COV2-2499-400-escape
# 19  200720  expt_13-16-none-0-reference  expt_15-COV2-2499-400-escape
# 20  200720  expt_13-16-none-0-reference  expt_16-COV2-2677-400-escape
# 21  200720  expt_13-16-none-0-reference  expt_16-COV2-2677-400-escape
# 22  200616   expt_7-11-none-0-reference  expt_10-COV2-2832-400-escape
# 23  200616   expt_7-11-none-0-reference  expt_10-COV2-2832-400-escape
# 24  200615    expt_3-6-none-0-reference      expt_3-CR3022-400-escape
# 25  200615    expt_3-6-none-0-reference      expt_3-CR3022-400-escape
# 26  210115  expt_82-86-none-0-reference  expt_82-LY-CoV555-400-escape
# 27  210115  expt_82-86-none-0-reference  expt_82-LY-CoV555-400-escape
# 28  200904  expt_24-33-none-0-reference  expt_24-REGN10933-400-escape
# 29  200904  expt_24-33-none-0-reference  expt_24-REGN10933-400-escape
# 30  200904  expt_24-33-none-0-reference  expt_25-REGN10987-400-escape
# 31  200904  expt_24-33-none-0-reference  expt_25-REGN10987-400-escape
# 32  201109  expt_74-78-none-0-reference      expt_75-S2D106-68-escape
# 33  201109  expt_74-78-none-0-reference      expt_75-S2D106-68-escape
# 34  201106  expt_68-73-none-0-reference       expt_69-S2E12-56-escape
# 35  201106  expt_68-73-none-0-reference       expt_69-S2E12-56-escape
# 36  210113  expt_79-81-none-0-reference       expt_80-S2H13-56-escape
# 37  210113  expt_79-81-none-0-reference       expt_80-S2H13-56-escape
# 38  210113  expt_79-81-none-0-reference      expt_81-S2H14-105-escape
# 39  210113  expt_79-81-none-0-reference      expt_81-S2H14-105-escape
# 40  201109  expt_74-78-none-0-reference       expt_74-S2H58-46-escape
# 41  201109  expt_74-78-none-0-reference       expt_74-S2H58-46-escape
# 42  210113  expt_79-81-none-0-reference       expt_79-S2H97-58-escape
# 43  210113  expt_79-81-none-0-reference       expt_79-S2H97-58-escape
# 44  201109  expt_74-78-none-0-reference       expt_77-S2X16-54-escape
# 45  201109  expt_74-78-none-0-reference       expt_77-S2X16-54-escape
# 46  201109  expt_74-78-none-0-reference     expt_78-S2X227-138-escape
# 47  201109  expt_74-78-none-0-reference     expt_78-S2X227-138-escape
# 48  201106  expt_68-73-none-0-reference      expt_71-S2X259-59-escape
# 49  201106  expt_68-73-none-0-reference      expt_71-S2X259-59-escape
# 50  201106  expt_68-73-none-0-reference       expt_70-S2X35-70-escape
# 51  201106  expt_68-73-none-0-reference       expt_70-S2X35-70-escape
# 52  201106  expt_68-73-none-0-reference       expt_72-S2X58-18-escape
# 53  201106  expt_68-73-none-0-reference       expt_72-S2X58-18-escape
# 54  201106  expt_68-73-none-0-reference        expt_73-S304-46-escape
# 55  201106  expt_68-73-none-0-reference        expt_73-S304-46-escape
# 56  201106  expt_68-73-none-0-reference       expt_68-S309-421-escape
# 57  201106  expt_68-73-none-0-reference       expt_68-S309-421-escape
#
#     frac_escape  pre_cells_sorted  post_cells_sorted
# 0         0.222         1907893.0        160000000.0
# 1         0.225          927804.0        160000000.0
# 2         0.078         1253185.0        160000000.0
# 3         0.104         1588138.0        160000000.0
# 4         0.057          522474.0        160000000.0
# 5         0.086          512138.0        160000000.0
# 6         0.069          853420.0        160000000.0
# 7         0.071          954885.0        160000000.0
# 8         0.155         1018697.0        160000000.0
# 9         0.110          927621.0        160000000.0
# 10        0.135         1933517.0                NaN
# 11        0.134         2145467.0                NaN
# 12        0.071          911426.0        160000000.0
# 13        0.029          393068.0        160000000.0
# 14        0.150         2323887.0                NaN
# 15        0.156         1828346.0                NaN
# 16        0.050          684856.0        160000000.0
# 17        0.044          582089.0        160000000.0
# 18        0.177         2593041.0        160000000.0
# 19        0.185         2655138.0        160000000.0
# 20        0.086         1243786.0        160000000.0
# 21        0.088         1457488.0        160000000.0
# 22        0.116         1525920.0        160000000.0
# 23        0.076          975400.0        160000000.0
# 24        0.148         1790556.0        160000000.0
# 25        0.091         1175925.0        160000000.0
# 26        0.161         1622745.0                NaN
# 27        0.169         1675156.0                NaN
# 28        0.174         1252342.0        160000000.0
# 29        0.154          984237.0        160000000.0
# 30        0.148         1155004.0        160000000.0
# 31        0.150         1091502.0        160000000.0
# 32        0.107          680797.0                NaN
# 33        0.062          500333.0                NaN
# 34        0.157         1431758.0                NaN
# 35        0.183         1615948.0                NaN
# 36        0.194         2156982.0                NaN
# 37        0.204         2037960.0                NaN
# 38        0.153         1568655.0                NaN
# 39        0.153         1680901.0                NaN
# 40        0.098          719772.0                NaN
# 41        0.116          870407.0                NaN
# 42        0.069          779263.0                NaN
# 43        0.081          867066.0                NaN
# 44        0.137          713984.0                NaN
# 45        0.131          734138.0                NaN
# 46        0.094          865531.0                NaN
# 47        0.085          786025.0                NaN
# 48        0.068          700753.0                NaN
# 49        0.064          600000.0                NaN
# 50        0.181         1600694.0                NaN
# 51        0.083          801564.0                NaN
# 52        0.222         2065573.0                NaN
# 53        0.141         1391912.0                NaN
# 54        0.123         1121146.0                NaN
# 55        0.155         1300000.0                NaN
# 56        0.100         1000774.0                NaN
# 57        0.199         1740195.0                NaN

# %% [markdown]
# Now unfold the samples of interest into the actual relevant barcode runs (this requires getting both the pre- and post-selection run for each sample):

# %%
barcode_runs_subset = (
    samples_subset
    .melt(id_vars=['name', 'library'],
          value_vars=['pre_sample', 'post_sample'],
          value_name='sample',
          var_name='sample_type')
    [['library', 'sample']]
    .drop_duplicates()
    .reset_index(drop=True)
    .merge(barcode_runs,
           how='left',
           on=['library', 'sample'],
           validate='one_to_one',
           )
    )

assert barcode_runs_subset['R1'].notnull().all(), 'some barcode runs missing R1'

barcode_runs_subset_file = 'barcode_runs_subset.csv'
print(f"Here are the subsetted barcode runs. Writing to {barcode_runs_subset_file}")
barcode_runs_subset.to_csv(barcode_runs_subset_file, index=False)
display(barcode_runs_subset)
# Out:
# Here are the subsetted barcode runs. Writing to barcode_runs_subset.csv
#    library                       sample    date  experiment antibody  \
# 0     lib1  expt_24-33-none-0-reference  200904  expt_24-33     none
# 1     lib2  expt_24-33-none-0-reference  200904  expt_24-33     none
# 2     lib1  expt_13-16-none-0-reference  200720  expt_13-16     none
# 3     lib2  expt_13-16-none-0-reference  200720  expt_13-16     none
# 4     lib1   expt_7-11-none-0-reference  200616   expt_7-11     none
# ..     ...                          ...     ...         ...      ...
# 73    lib2      expt_72-S2X58-18-escape  201106     expt_72    S2X58
# 74    lib1       expt_73-S304-46-escape  201106     expt_73     S304
# 75    lib2       expt_73-S304-46-escape  201106     expt_73     S304
# 76    lib1      expt_68-S309-421-escape  201106     expt_68     S309
# 77    lib2      expt_68-S309-421-escape  201106     expt_68     S309
#
#    concentration concentration_units           group  selection  frac_escape  \
# 0              0           ng_per_mL  clinical_serum  reference          NaN
# 1              0           ng_per_mL  clinical_serum  reference          NaN
# 2              0           ng_per_mL            none  reference          NaN
# 3              0           ng_per_mL            none  reference          NaN
# 4              0           ng_per_mL            none  reference          NaN
# ..           ...                 ...             ...        ...          ...
# 73            18           ng_per_mL             Vir     escape        0.141
# 74            46           ng_per_mL             Vir     escape        0.123
# 75            46           ng_per_mL             Vir     escape        0.155
# 76           421           ng_per_mL             Vir     escape        0.100
# 77           421           ng_per_mL             Vir     escape        0.199
#
#     cells_sorted                                                 R1
# 0    160000000.0  /shared/ngs/illumina/agreaney/200914_D00300_10...
# 1    160000000.0  /shared/ngs/illumina/agreaney/200914_D00300_10...
# 2    160000000.0  /shared/ngs/illumina/agreaney/200727_D00300_10...
# 3    160000000.0  /shared/ngs/illumina/agreaney/200727_D00300_10...
# 4    160000000.0  /shared/ngs/illumina/agreaney/200618_D00300_09...
# ..           ...                                                ...
# 73     1391912.0  /shared/ngs/illumina/tstarr/201123_D00300_1119...
# 74     1121146.0  /shared/ngs/illumina/tstarr/201123_D00300_1119...
# 75     1300000.0  /shared/ngs/illumina/tstarr/201123_D00300_1119...
# 76     1000774.0  /shared/ngs/illumina/tstarr/201123_D00300_1119...
# 77     1740195.0  /shared/ngs/illumina/tstarr/201123_D00300_1119...
#
# [78 rows x 12 columns]
